# %%
import numpy as np
import pandas as pd

# %%
######
# website : https://ess.sikt.no/en/datafile/a93fed5b-3858-4e86-bdae-dfcf5bbc9bf9/33?tab=0

data = pd.read_csv("data/ESS10/ESS10.csv")
data.shape
# Out:
# /tmp/ipykernel_2512/4291870769.py:5: DtypeWarning: Columns (166,172,174,607,608) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("data/ESS10/ESS10.csv")
# (37611, 618)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.DataFrame(data[["netusoft"]])
sns.histplot(df)
plt.xticks(ticks=[1,2,3,4,5,7,8,9], rotation=90, labels=['Never','Only occasionally','A few times a week','Most days','Every day','Refusal*','Dont know*','No answer*'])
plt.legend(labels=['Internet use, how often'])

# %%
data.groupby('cntry').count()
#grouped by country
# Out:
#        name  essround  edition  proddate  idno  dweight  pspwght  pweight  \
# cntry
# BE     1341      1341     1341      1341  1341     1341     1341     1341
# BG     2718      2718     2718      2718  2718     2718     2718     2718
# CH     1523      1523     1523      1523  1523     1523     1523     1523
# CZ     2476      2476     2476      2476  2476     2476     2476     2476
# EE     1542      1542     1542      1542  1542     1542     1542     1542
# FI     1577      1577     1577      1577  1577     1577     1577     1577
# FR     1977      1977     1977      1977  1977     1977     1977     1977
# GB     1149      1149     1149      1149  1149     1149     1149     1149
# GR     2799      2799     2799      2799  2799     2799     2799     2799
# HR     1592      1592     1592      1592  1592     1592     1592     1592
# HU     1849      1849     1849      1849  1849     1849     1849     1849
# IE     1770      1770     1770      1770  1770     1770     1770     1770
# IS      903       903      903       903   903      903      903      903
# IT     2640      2640     2640      2640  2640     2640     2640     2640
# LT     1659      1659     1659      1659  1659     1659     1659     1659
# ME     1278      1278     1278      1278  1278     1278     1278     1278
# MK     1429      1429     1429      1429  1429     1429     1429     1429
# NL     1470      1470     1470      1470  1470     1470     1470     1470
# NO     1411      1411     1411      1411  1411     1411     1411     1411
# PT     1838      1838     1838      1838  1838     1838     1838     1838
# SI     1252      1252     1252      1252  1252     1252     1252     1252
# SK     1418      1418     1418      1418  1418     1418     1418     1418
#
#        anweight  nwspol  ...  vinwe  inwde  jinws  jinwe  inwtm  mode  domain  \
# cntry                    ...
# BE         1341    1341  ...   1341   1341   1341   1341   1339  1341    1341
# BG         2718    2718  ...   2426   2718   2718   2718   2687  2718       0
# CH         1523    1523  ...   1523   1523   1523   1523   1486  1523       0
# CZ         2476    2476  ...   2476   2476   2476   2476   2476  2476       0
# EE         1542    1542  ...   1541   1541   1542   1542   1514  1542       0
# FI         1577    1577  ...      0   1576   1232   1232   1565  1577       0
# FR         1977    1977  ...   1977   1977   1977   1977   1930  1977    1977
# GB         1149    1149  ...   1136   1114      0      0   1114  1149       0
# GR         2799    2799  ...   2765   2799   2797   2794   2791  2799       0
# HR         1592    1592  ...   1592   1592   1592   1585   1592  1592    1592
# HU         1849    1849  ...   1842   1849   1831   1824   1835  1849    1849
# IE         1770    1770  ...   1770   1770   1770   1770   1756  1770       0
# IS          903     903  ...    879    903    881    871    894   903     903
# IT         2640    2640  ...   2640   2640   2601   2597   2631  2640    2640
# LT         1659    1659  ...   1659   1658   1659   1659   1594  1659    1659
# ME         1278    1278  ...      0   1278   1278   1278   1268  1278       0
# MK         1429    1429  ...   1428   1429   1425   1422   1422  1429       0
# NL         1470    1470  ...   1470   1470   1470   1470   1462  1470       0
# NO         1411    1411  ...   1411   1411   1408   1408   1406  1411       0
# PT         1838    1838  ...   1838   1838   1838   1838   1837  1838    1838
# SI         1252    1252  ...    585   1249   1243   1249   1228  1252       0
# SK         1418    1418  ...   1326   1418   1407   1405   1397  1418    1418
#
#        prob  stratum   psu
# cntry
# BE     1341     1341  1341
# BG     2718     2718  2718
# CH     1523     1523  1523
# CZ     2476     2476  2476
# EE     1542     1542  1542
# FI     1577     1577  1577
# FR     1977     1977  1977
# GB     1149     1149  1149
# GR     2799     2799  2799
# HR     1592     1592  1592
# HU     1849     1849  1849
# IE     1770     1770  1770
# IS      903      903   903
# IT     2640     2640  2640
# LT     1659     1659  1659
# ME     1278     1278  1278
# MK     1429     1429  1429
# NL     1470     1470  1470
# NO     1411     1411  1411
# PT     1838     1838  1838
# SI     1252     1252  1252
# SK     1418     1418  1418
#
# [22 rows x 617 columns]

# %%
dict_df = {
    "Human values" : 1,
    "Impact of COVID-19" : 1,
    "Test questions" : 1
}

# %%
df_test = data.iloc[:, 540:549]
dict_df['Test questions'] = df_test
dict_df['Test questions']
# Out:
#        testii1  testii2  testii3  testii4  testii5  testii6  testii7  testii8  \
# 0            6        6        6        2        2        3       66       66
# 1            6        6        6       66       66       66        4        4
# 2            6        6        6        6        5        4       66       66
# 3            6        6        6        4        4        4       66       66
# 4            6        6        6       66       66       66        8        7
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 37606        6        6        6       66       66       66        2        6
# 37607        6        6        6       66       66       66        9        3
# 37608        6        6        6       66       66       66        5        4
# 37609        6        6        6        4        5        3       66       66
# 37610        6        6        6       66       66       66        6        7
#
#        testii9
# 0           66
# 1            4
# 2           66
# 3           66
# 4            6
# ...        ...
# 37606        6
# 37607        6
# 37608        6
# 37609       66
# 37610        7
#
# [37611 rows x 9 columns]

# %%
df_human_values = data.iloc[:, 519:540]
dict_df['Human values'] = df_human_values
dict_df['Human values']
# Out:
#        ipcrtiv  imprich  ipeqopt  ipshabt  impsafe  impdiff  ipfrule  ipudrst  \
# 0            4        3        1        4        2        4        4        2
# 1            2        3        2        3        2        3        3        1
# 2            2        4        1        2        3        1        3        3
# 3            2        1        2        1        1        1        1        2
# 4            3        2        2        4        3        4        2        2
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 37606        3        4        2        3        3        5        3        4
# 37607        3        4        1        3        3        3        3        2
# 37608        2        2        2        3        2        3        2        2
# 37609        2        3        2        2        1        2        2        2
# 37610        2        2        2        2        2        2        2        2
#
#        ipmodst  ipgdtim  ...  iphlppl  ipsuces  ipstrgv  ipadvnt  ipbhprp  \
# 0            3        2  ...        2        2        2        5        3
# 1            5        3  ...        1        2        1        3        2
# 2            3        2  ...        3        3        2        3        3
# 3            2        1  ...        1        1        1        7        1
# 4            3        2  ...        2        4        2        5        1
# ...        ...      ...  ...      ...      ...      ...      ...      ...
# 37606        4        5  ...        3        4        2        6        2
# 37607        4        3  ...        3        3        2        3        3
# 37608        3        2  ...        2        4        2        4        3
# 37609        4        3  ...        2        2        3        2        1
# 37610        2        2  ...        2        2        2        2        2
#
#        iprspot  iplylfr  impenv  imptrad  impfun
# 0            2        2       3        3       2
# 1            2        2       2        1       2
# 2            3        3       3        1       3
# 3            1        1       1        1       1
# 4            3        2       2        3       3
# ...        ...      ...     ...      ...     ...
# 37606        2        3       2        3       3
# 37607        3        3       3        3       3
# 37608        3        4       2        2       3
# 37609        1        2       2        1       3
# 37610        2        2       2        2       2
#
# [37611 rows x 21 columns]

# %%
df_covid = data.iloc[:, 549:583]
dict_df['Impact of COVID-19'] = df_covid
dict_df['Impact of COVID-19']
# Out:
#        secgrdec  scidecpb  admc19  panpriph  panmonpb  govpriph  govmonpb  \
# 0             4         3       2        66        66         5         7
# 1             3         3       2        66        66         5         5
# 2             4         5       1         7         3        66        66
# 3             8         8       1         2         5        66        66
# 4             5         5       1         3         5        66        66
# ...         ...       ...     ...       ...       ...       ...       ...
# 37606         5         5       2        66        66         5        10
# 37607         4         4       1         5         9        66        66
# 37608         3         3       1         0         6        66        66
# 37609         5         5       2        66        66         3         6
# 37610         4         4       2        66        66         3         7
#
#        panfolru  panclobo  panresmo  ...  hapfoc19  hapnoc19  hapnwc19  \
# 0             2         9         8  ...         0         1         0
# 1             6         5         5  ...         0         1         0
# 2             3         8         8  ...         0         1         0
# 3             2         5         5  ...         0         0         0
# 4             2         7         3  ...         0         1         0
# ...         ...       ...       ...  ...       ...       ...       ...
# 37606         6        88        10  ...         0         0         1
# 37607         6         5         0  ...         0         1         0
# 37608         2         9         7  ...         0         0         0
# 37609         4         5         5  ...         0         1         0
# 37610         5         5         4  ...         0         1         0
#
#        hapnpc19  haprec19  hapdkc19  hapnac19  icvacc19  getavc19  getnvc19
# 0             0         0         0         0         1         2         6
# 1             0         0         0         0         1         2         6
# 2             0         0         0         0         1         1         6
# 3             0         0         0         0         1         3         6
# 4             0         0         0         0         1         2         6
# ...         ...       ...       ...       ...       ...       ...       ...
# 37606         0         0         0         0         9         2         9
# 37607         0         0         0         0         9         2         9
# 37608         0         0         0         0         9         1         9
# 37609         0         0         0         0         9         2         9
# 37610         0         0         0         0         9         2         9
#
# [37611 rows x 34 columns]

# %%
df_dig_social_contacts = data.iloc[:, 449:519]
dict_df['Digital social contacts in works and family life'] = df_dig_social_contacts
dict_df['Digital social contacts in works and family life']
# Out:
#        acchome  accwrk  accmove  accoth  accnone  accref  accdk  accna  \
# 0            1       0        1       1        0       0      0      0
# 1            1       0        0       1        0       0      0      0
# 2            1       0        0       1        0       0      0      0
# 3            0       1        0       0        0       0      0      0
# 4            1       1        1       1        0       0      0      0
# ...        ...     ...      ...     ...      ...     ...    ...    ...
# 37606        1       0        0       0        0       0      0      0
# 37607        1       0        1       1        0       0      0      0
# 37608        1       0        0       1        0       0      0      0
# 37609        1       1        1       1        0       0      0      0
# 37610        1       0        0       0        0       0      0      0
#
#        fampref  famadvs  ...  wrkextra  colprop  colhlp  colspeak  colscrn  \
# 0            2        4  ...        66       66       6        66       66
# 1            5        5  ...        66       66       6        66       66
# 2            3        3  ...        66       66       6        66       66
# 3            1        1  ...         8        3       2         3        7
# 4            3        3  ...        10        1       2         2        7
# ...        ...      ...  ...       ...      ...     ...       ...      ...
# 37606        2        2  ...        66       66       6        66       66
# 37607        5        5  ...        66       66       6        66       66
# 37608        4        4  ...         5        4       2         5        4
# 37609        5        5  ...         3        2       2         2        6
# 37610        2        2  ...         6        3       2         1        4
#
#        colphone  colcom  c19spwrk  c19mcwrk  mcwrkhom
# 0            66      66        66        66        66
# 1            66      66        66        66        66
# 2            66      66        66        66        66
# 3             7       1         4         3        88
# 4             3       4         3         3         6
# ...         ...     ...       ...       ...       ...
# 37606        66      66        66        66        66
# 37607        66      66        66        66        66
# 37608         3       4         3         3         6
# 37609         2       3         3         3         1
# 37610         6       4         1         2        88
#
# [37611 rows x 70 columns]

# %%
df_social_demographics = data.iloc[:, 268:449] 
dict_df['Socio-demographics'] = df_social_demographics
dict_df['Socio-demographics']
# Out:
#        rshpsts  rshpsmk  rshpsgb  lvgptnea  dvrcdeva  marsts  marstmk  \
# 0           66      NaN      NaN         2         2       6      NaN
# 1           66      NaN      NaN         2         2       6      NaN
# 2            1      NaN      NaN         1         2      66      NaN
# 3           66      NaN      NaN         2         1       4      NaN
# 4           66      NaN      NaN         2         2       6      NaN
# ...        ...      ...      ...       ...       ...     ...      ...
# 37606        3      NaN      NaN         6         2       1      NaN
# 37607       66      NaN      NaN         2         1       4      NaN
# 37608        1      NaN      NaN         2         2      66      NaN
# 37609        1      NaN      NaN         2         2      66      NaN
# 37610        1      NaN      NaN         7         2      66      NaN
#
#        marstgb  maritalb  chldhhe  ...  edumcgb1  edumbgb2  edagemgb  emprm14  \
# 0          NaN         6        2  ...       NaN       NaN       NaN        1
# 1          NaN         6        2  ...       NaN       NaN       NaN        2
# 2          NaN         1        2  ...       NaN       NaN       NaN        1
# 3          NaN         4        1  ...       NaN       NaN       NaN        3
# 4          NaN         6        2  ...       NaN       NaN       NaN        1
# ...        ...       ...      ...  ...       ...       ...       ...      ...
# 37606      NaN         1        6  ...       NaN       NaN       NaN        3
# 37607      NaN         4        1  ...       NaN       NaN       NaN        1
# 37608      NaN         1        2  ...       NaN       NaN       NaN        3
# 37609      NaN         1        1  ...       NaN       NaN       NaN        1
# 37610      NaN         1        6  ...       NaN       NaN       NaN        8
#
#        occm14b  atncrse  anctry1  anctry2  regunit  region
# 0            5        2   444444    11020        2    BE24
# 1            3        1    11021    11020        2    BE24
# 2            3        2    11050   555555        2    BE33
# 3           66        2    11020   888888        2    BE21
# 4            3        2    11040   555555        2    BE24
# ...        ...      ...      ...      ...      ...     ...
# 37606       66        2    15130   888888        3   SK021
# 37607        9        2    15130   555555        3   SK022
# 37608       66        2    15130   555555        3   SK041
# 37609        4        1    15130   555555        3   SK021
# 37610       88        1    15130    15020        3   SK031
#
# [37611 rows x 181 columns]

# %%
df_social_exclusion = data.iloc[:,106:177]
df_social_exclusion
dict_df['Subjective well-being, social exclusion, religion, national and ethnic identity'] = df_social_exclusion
dict_df['Subjective well-being, social exclusion, religion, national and ethnic identity']
# Out:
#        happy  sclmeet  inprdsc  sclact  crmvct  aesfdrk  health  hlthhmp  \
# 0          7        5        2       2       8        2       2        3
# 1          6        4        4       2       2        2       2        3
# 2          8        4        2       1       2        1       2        1
# 3         10        5        3       2       2        2       1        3
# 4          7        6        4       2       2        1       1        3
# ...      ...      ...      ...     ...     ...      ...     ...      ...
# 37606      5        3        1       2       2        3       3        3
# 37607      8        7        1       3       2        1       2        3
# 37608      7        3        3       3       2        2       2        3
# 37609      7        6        1       4       2        2       2        3
# 37610      7        4        0       3       2        1       1        3
#
#        atchctr  atcherp  ...  livecnta  lnghom1  lnghom2  feethngr  facntr  \
# 0            7        6  ...      6666      ENG      DUT         2       2
# 1            3        3  ...      2013      DUT      000         1       1
# 2            8        9  ...      2000      FRE      000         1       2
# 3            9        8  ...      2015      ARA      DUT         1       2
# 4            9        9  ...      1993      DUT      000         1       2
# ...        ...      ...  ...       ...      ...      ...       ...     ...
# 37606       10        8  ...      6666      SLO      000         1       1
# 37607       10        9  ...      6666      SLO      000         1       1
# 37608        9        7  ...      6666      SLO      000         2       1
# 37609        6        7  ...      6666      SLO      000         1       1
# 37610        6        6  ...      6666      SLO      000         1       1
#
#        fbrncntc  mocntr  mbrncntc  ccnthum  ccrdprs
# 0            NG       2        NG        4        5
# 1          6666       1      6666        3        5
# 2            FR       2        FR        4        8
# 3            IQ       2        IQ       88       88
# 4            NL       2        NL        4        9
# ...         ...     ...       ...      ...      ...
# 37606      6666       1      6666        2        3
# 37607      6666       1      6666       55       66
# 37608      6666       1      6666        3        6
# 37609      6666       1      6666        5        9
# 37610      6666       1      6666        4        6
#
# [37611 rows x 71 columns]

# %%
data.columns.get_loc('tmpdca')
#dict_df.keys()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tmpdca'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [20], line 1
# ----> 1 data.columns.get_loc('tmpdca')
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/indexes/base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'tmpdca'

# %%
"Gender, Year of birth and Household grid"
"Understanding of democracy"
"Subjective well-being, social exclusion, religion, national and ethnic identity"
"Politics"
"Media and social trust"
"Identifier and weight variables"

# %%
from matplotlib import pyplot as plt

df = dict_df['Subjective well-being, social exclusion, religion, national and ethnic identity']
df = df[['happy']][df['happy']<12]
df
plt.hist(df)
plt.xlabel('Happiness')
plt.ylabel('European population')
plt.xticks(ticks=[0,10], rotation=90, labels=['Extremely unhappy','Extremely happy'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f540f890bb0>,
#   <matplotlib.axis.XTick at 0x7f540f893eb0>],
#  [Text(0, 0, 'Extremely unhappy'), Text(10, 0, 'Extremely happy')])

# %% [markdown]
# # Experiments on 18/03/2024

# %% [markdown]
# ## Member of a group discriminated against in this country.

# %%
# yes = 1
data[data['dscrgrp']==1].shape
# Out:
# (2872, 618)

# %%
# no = 2
data[data['dscrgrp']==2].shape
# Out:
# (34238, 618)

# %%
# 7, 8, 9 = refusal, don't know, no answer
data[(data['dscrgrp']==7) | (data['dscrgrp']==8) | (data['dscrgrp']==9)].shape # or data['dscrgrp']==9 ].shape
# Out:
# (501, 618)

# %% [markdown]
# ## By gender

# %%
# male = 1
data[data['gndr']==1].shape
# Out:
# (17463, 618)

# %%
# female = 2
data[data['gndr']==2].shape
# Out:
# (20148, 618)

# %%
# no answer = 9
data[data['gndr']==9].shape
# Out:
# (0, 618)

# %% [markdown]
# ## By age (bunches of 10 years)

# %%
# between 15 and 20 years (minimal age = 15 years)
data[(data['agea']>=15) & (data['agea']<=20)].set_index('agea').shape
# Out:
# (1971, 617)

# %%
# between 21 and 30 years
data[(data['agea']>=21) & (data['agea']<=30)].set_index('agea').shape
# Out:
# (4326, 617)

# %%
# between 31 and 40 years
data[(data['agea']>=31) & (data['agea']<=40)].set_index('agea').shape
# Out:
# (5454, 617)

# %%
# between 41 and 50 years
data[(data['agea']>=41) & (data['agea']<=50)].set_index('agea').shape
# Out:
# (6228, 617)

# %%
# between 51 and 60 years
data[(data['agea']>=51) & (data['agea']<=60)].set_index('agea').shape
# Out:
# (6708, 617)

# %%
# between 61 and 70 years
data[(data['agea']>=61) & (data['agea']<=70)].set_index('agea').shape
# Out:
# (6423, 617)

# %%
# between 71 and 80 years
data[(data['agea']>=71) & (data['agea']<=80)].set_index('agea').shape
# Out:
# (4492, 617)

# %%
# between 81 and 90 years, it goes until 90 years
data[(data['agea']>=81) & (data['agea']<=90)].set_index('agea').shape
# Out:
# (1717, 617)

# %%
# not available = 999
data[data['agea']==999].set_index('agea').shape
# Out:
# (292, 617)

# %%
data_fil = data[data['agea']!=999]
x = data_fil.groupby('agea')[['agea']].count()
xx = data[data['agea']!=999]
#yy = np.arange(0,90,1)
plt.hist(xx)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/matplotlib/axis.py:1506, in Axis.convert_units(self, x)
#    1505 try:
# -> 1506     ret = self.converter.convert(x, self.units, self)
#    1507 except Exception as e:
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/matplotlib/category.py:68, in StrCategoryConverter.convert(value, unit, axis)
#      67 # force an update so it also does type checking
# ---> 68 unit.update(values)
#      69 return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/matplotlib/category.py:227, in UnitData.update(self, data)
#     225 for val in OrderedDict.fromkeys(data):
#     226     # OrderedDict just iterates over unique values in data.
# --> 227     _api.check_isinstance((str, bytes), value=val)
#     228     if convertible:
#     229         # this will only be called so long as convertible is True.
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/matplotlib/_api/__init__.py:93, in check_isinstance(_types, **kwargs)
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a int
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In [140], line 5
#       3 xx = data[data['agea']!=999]
#       4 #yy = np.arange(0,90,1)
# ----> 5 plt.hist(xx)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/matplotlib/pyplot.py:2600, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2594 @_copy_docstring_and_deprecators(Axes.hist)
#    2595 def hist(
#    2596         x, bins=None, range=None, density=False, weights=None,
#    2597         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2598         orientation='vertical', rwidth=None, log=False, color=None,
#    2599         label=None, stacked=False, *, data=None, **kwargs):
# -> 2600     return gca().hist(
#    2601         x, bins=bins, range=range, density=density, weights=weights,
#    2602         cumulative=cumulative, bottom=bottom, histtype=histtype,
#    2603         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2604         color=color, label=label, stacked=stacked,
#    2605         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/matplotlib/__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/matplotlib/axes/_axes.py:6562, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6560 if orientation == "vertical":
#    6561     convert_units = self.convert_xunits
# -> 6562     x = [*self._process_unit_info([("x", x[0])], kwargs),
#    6563          *map(convert_units, x[1:])]
#    6564 else:  # horizontal
#    6565     convert_units = self.convert_yunits
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/matplotlib/artist.py:253, in Artist.convert_xunits(self, x)
#     251 if ax is None or ax.xaxis is None:
#     252     return x
# --> 253 return ax.xaxis.convert_units(x)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/matplotlib/axis.py:1508, in Axis.convert_units(self, x)
#    1506     ret = self.converter.convert(x, self.units, self)
#    1507 except Exception as e:
# -> 1508     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1509                                  f'units: {x!r}') from e
#    1510 return ret
#
# ConversionError: Failed to convert value(s) to axis units: array(['6666', 'SA', 'FR', ..., '6666', '6666', '6666'], dtype=object)

# %% [markdown]
# ## Some exploration on weighting
